# %%
import rdkit
from rdkit import Chem

# %%
mol = Chem.MolFromSmiles('[12*][n:12]1[n:11][cH:10][c:9](-[c:8]2[cH:7][cH:6][c:5]([S:2]([CH3:1])(=[O:3])=[O:4])[cH:24][cH:23]2)[c:15](-[c:16]2[cH:17][cH:18][c:19]([F:20])[cH:21][cH:22]2)[c:13]1=[O:14]')

# %%
print(mol)

# %%
mol

# %%
mol1 = Chem.MolFromSmiles('[11*][c:30]([13*])[cH:31][cH:32][c:27]([S:26][CH3:25])[cH:28][cH:29][12*]')
# Out:
# RDKit ERROR: [22:07:36] non-ring atom 1 marked aromatic
# [22:07:36] non-ring atom 1 marked aromatic

# %%
mol1

# %%
mol2 = Chem.MolFromSmiles('[CH3:1][S:2](=[O:3])(=[O:4])[c:5]1[cH:6][cH:7][c:8](-[c:9]2[cH:10][n:11][nH:12][c:13](=[O:14])[c:15]2-[c:16]2[cH:17][cH:18][c:19]([F:20])[cH:21][cH:22]2)[cH:23][cH:24]1.[CH3:25][S:26][c:27]([cH:28][cH:29])[cH:32][cH:31][c:30]')
# Out:
# RDKit ERROR: [22:09:37] non-ring atom 26 marked aromatic
# [22:09:37] non-ring atom 26 marked aromatic

# %%
mol2

# %%
mol3 = Chem.MolFromSmiles('[CH3:1][S:2](=[O:3])(=[O:4])[c:5]1[cH:6][cH:7][c:8](-[c:9]2[cH:10][n:11][n:12](-[c:30]3[cH:29][cH:28][c:27]([S:26][CH3:25])[cH:32][cH:31]3)[c:13](=[O:14])[c:15]2-[c:16]2[cH:17][cH:18][c:19]([F:20])[cH:21][cH:22]2)[cH:23][cH:24]1')

# %%
mol3

# %%
fragments = Chem.FragmentOnBonds(mol3, [11, 12], addDummies=True)

# %%
fragments

# %%
from rdkit import Chem
from rdkit.Chem import AllChem
m = Chem.MolFromSmiles('[CH3:1][S:2](=[O:3])(=[O:4])[c:5]1[cH:6][cH:7][c:8](-[c:9]2[cH:10][n:11][n:12](-[c:30]3[cH:29][cH:28][c:27]([S:26][CH3:25])[cH:32][cH:31]3)[c:13](=[O:14])[c:15]2-[c:16]2[cH:17][cH:18][c:19]([F:20])[cH:21][cH:22]2)[cH:23][cH:24]1')

# %%
print(m)

# %% [markdown]
# m

# %%
mol = Chem.RWMol(m)

# %%
mol.RemoveBond(11, 12)

# %%
from rdkit import Chem
frags_mol_list = Chem.GetMolFrags(mol, asMols=True, sanitizeFrags=False)

frag2 = Chem.MolFromSmiles('[CH3:1][S:2](=[O:3])(=[O:4])[c:5]1[cH:6][cH:7][c:8](-[c:9]2[cH:10][n:11][n:12][c:13](=[O:14])[c:15]2-[c:16]2[cH:17][cH:18][c:19]([F:20])[cH:21][cH:22]2)[cH:23][cH:24]1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_219197/1629416036.py in <module>
#       1 from rdkit import Chem
# ----> 2 frags_mol_list = Chem.GetMolFrags(mol, asMols=True, sanitizeFrags=False)
#       3
#       4 frag2 = Chem.MolFromSmiles('[CH3:1][S:2](=[O:3])(=[O:4])[c:5]1[cH:6][cH:7][c:8](-[c:9]2[cH:10][n:11][n:12][c:13](=[O:14])[c:15]2-[c:16]2[cH:17][cH:18][c:19]([F:20])[cH:21][cH:22]2)[cH:23][cH:24]1')
#
# NameError: name 'mol' is not defined

# %%
frag2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_219197/3945429943.py in <module>
# ----> 1 frag2
#
# NameError: name 'frag2' is not defined
